# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/create_knowledge_base/blob/main/Create_chunks_from_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 69.3 MB/s eta 0:00:00

# %%
# install first:
# pip install pymupdf

import pymupdf as fitz
import os
import re
from pathlib import Path

# =========================
# CONFIG
# =========================
PDF_PATH = "/content/Range.pdf"          # your pdf file
OUTPUT_DIR = "Range_output"
WORDS_PER_CHUNK = 3500

# =========================
# CREATE OUTPUT DIRECTORY
# =========================
Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

# =========================
# READ PDF
# =========================
doc = fitz.open(PDF_PATH)

all_text = []

for page in doc:
    text = page.get_text()
    all_text.append(text)

doc.close()

full_text = "\n".join(all_text)

# =========================
# CLEAN TEXT
# =========================
full_text = re.sub(r'\s+', ' ', full_text).strip()

# =========================
# SPLIT INTO WORDS
# =========================
words = full_text.split()

# =========================
# CHUNKING
# =========================
chunks = []

for i in range(0, len(words), WORDS_PER_CHUNK):
    chunk_words = words[i:i + WORDS_PER_CHUNK]
    chunk_text = " ".join(chunk_words)
    chunks.append(chunk_text)

# =========================
# SAVE CHUNKS
# =========================
for idx, chunk in enumerate(chunks, start=1):
    filename = f"part{idx:02d}.txt"
    filepath = os.path.join(OUTPUT_DIR, filename)

    with open(filepath, "w", encoding="utf-8") as f:
        f.write(chunk)

    print(f"Saved: {filepath}")

print(f"\nDone. Total chunks created: {len(chunks)}")
# Out:
# Saved: Range_output/part01.txt
# Saved: Range_output/part02.txt
# Saved: Range_output/part03.txt
# Saved: Range_output/part04.txt
# Saved: Range_output/part05.txt
# Saved: Range_output/part06.txt
# Saved: Range_output/part07.txt
# Saved: Range_output/part08.txt
# Saved: Range_output/part09.txt
# Saved: Range_output/part10.txt
# Saved: Range_output/part11.txt
# Saved: Range_output/part12.txt
# Saved: Range_output/part13.txt
# Saved: Range_output/part14.txt
# Saved: Range_output/part15.txt
# Saved: Range_output/part16.txt
# Saved: Range_output/part17.txt
# Saved: Range_output/part18.txt
# Saved: Range_output/part19.txt
# Saved: Range_output/part20.txt
# Saved: Range_output/part21.txt
# Saved: Range_output/part22.txt
# Saved: Range_output/part23.txt
# Saved: Range_output/part24.txt
# Saved: Range_output/part25.txt
# Saved: Range_output/part26.txt
# Saved: Range_output/part27.txt
# Saved: Range_output/part28.txt
# Saved: Range_output/part29.txt
# Saved: Range_output/part30.txt
# Saved: Range_output/part31.txt
# Saved: Range_output/part32.txt
#
# Done. Total chunks created: 32

# %%
import shutil

# zip the folder
shutil.make_archive("Range_output", "zip", "Range_output")

print("ZIP created: Range_output.zip")
# Out:
# ZIP created: Range_output.zip
